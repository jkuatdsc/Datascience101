# %%
# Import the required libraries: Pandas, Numpy, Matplotlib and  Seaborn

import pandas as pd  # For data munging, manipulations and preparation        
import numpy as np  # for numerical and mathematical calculations
import seaborn as sns # For statistical data visualization
import matplotlib.pyplot as plt  # For plotting variety of graphs(histograms, heatplots, lineplots
# %matplotlib inline
import warnings                   # To ignore the warnings
warnings.filterwarnings("ignore")

# %%
# Let us load and read the data from the csv file then print the top 5 rows  to understand the various data columns.

df=pd.read_csv("Train.csv")
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# Display the last data  columns in the data set
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.sample()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 326  LP002068   Male      No          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 326             4917                0.0       130.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 326             0.0         Rural           Y

# %%
# Checking the  Missing Values

missing_df = df.isnull().sum(axis=0).reset_index()
missing_df.columns = ['Column_Name', 'Missing_Count']
missing_df = missing_df[missing_df['Missing_Count']>0]
missing_df = missing_df.sort_values(by='Missing_Count')
missing_df
# Out:
#          Column_Name  Missing_Count
# 2            Married              3
# 1             Gender             13
# 9   Loan_Amount_Term             14
# 3         Dependents             15
# 8         LoanAmount             22
# 5      Self_Employed             32
# 10    Credit_History             50

# %%
## Percentage of Missing Values
plt.figure(figsize=(15,10))
plt.subplot(233)
sns.heatmap(pd.DataFrame(df.isnull().sum()/df.shape[0]*100),annot=True,
            cmap=sns.color_palette("cool"),linewidth=1,linecolor="white")
plt.title("Missing Values")

plt.subplots_adjust(wspace = 0.0)

# %%
# Check the instances(rows) and attributes(columns) in the dataset: Size and Dimension of the dataframe
df.shape
print("DataFrame Dimenisons:", df.shape)

# %%
df.info()

# %%
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
df['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
df['Credit_History'].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
# Checking the  Missing Values

missing_df = df.isnull().sum(axis=0).reset_index()
missing_df.columns = ['Column_Name', 'Missing_Count']
missing_df = missing_df[missing_df['Missing_Count']>0]
missing_df = missing_df.sort_values(by='Missing_Count')
missing_df
# Out:
#          Column_Name  Missing_Count
# 2            Married              3
# 1             Gender             13
# 9   Loan_Amount_Term             14
# 3         Dependents             15
# 8         LoanAmount             22
# 5      Self_Employed             32
# 10    Credit_History             50

# %%
## Statistics on the numerical data

df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
## Descriptive Statistics Summary of al columns:

df.describe(include="all")
# Out:
#        Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# count     601     611        599       614           582       614.000000
# unique      2       2          4         2             2              NaN
# top      Male     Yes          0  Graduate            No              NaN
# freq      489     398        345       480           500              NaN
# mean      NaN     NaN        NaN       NaN           NaN      5403.459283
# std       NaN     NaN        NaN       NaN           NaN      6109.041673
# min       NaN     NaN        NaN       NaN           NaN       150.000000
# 25%       NaN     NaN        NaN       NaN           NaN      2877.500000
# 50%       NaN     NaN        NaN       NaN           NaN      3812.500000
# 75%       NaN     NaN        NaN       NaN           NaN      5795.000000
# max       NaN     NaN        NaN       NaN           NaN     81000.000000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df.describe().plot(kind = "area",fontsize=27, figsize = (20,8), table = True,colormap="rainbow")
plt.xlabel('Statistics',)
plt.ylabel('Value')
plt.title("General Statistics of Loans Dataset")
# Out:
# Text(0.5, 1.0, 'General Statistics of Loans Dataset')

# %%
# Checking the Column types and Count value

ctype = df.dtypes.reset_index()
ctype.columns = ["Count", "Column Type"]
ctype.groupby("Column Type").aggregate('count').reset_index()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
## Method to display the columns in the data set

df.count().to_frame().T
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      614     601      611         599        614            582
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              614                614         592               600
#
#    Credit_History  Property_Area  Loan_Status
# 0             564            614          614

# %%
 # Renaming the Columns

a=df.rename(columns={'Gender':'Sex'},inplace=True)
a

# %%
df.columns
# Out:
# Index(['Sex', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# Drop Column

df.drop('Loan_ID', axis=1, inplace=True)
df.head(3)
# Out:
#   Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0  Graduate            No             5849
# 1   Male     Yes          1  Graduate            No             4583
# 2   Male     Yes          0  Graduate           Yes             3000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y

# %%
#  Dropping Columns in a DataFrame
# Categories of data in a dataset not useful to you.

to_drop = ["Loan_ID", "Married"]
df.drop(to_drop, inplace=True, axis=1)

# %%
# Replacing the existing Index Loan ID  with Gender Column as the set index

df = df.set_index('Loan_Status')
df.head()

# %%
# Setting the index of the dataset after removing the Loan ID Column

df.set_index('Gender', inplace = True)
df.head()
# Out:
#          Loan_ID Married Dependents     Education Self_Employed  \
# Gender
# Male    LP001002      No          0      Graduate            No
# Male    LP001003     Yes          1      Graduate            No
# Male    LP001005     Yes          0      Graduate           Yes
# Male    LP001006     Yes          0  Not Graduate            No
# Male    LP001008      No          0      Graduate            No
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Gender
# Male               5849                0.0         NaN             360.0
# Male               4583             1508.0       128.0             360.0
# Male               3000                0.0        66.0             360.0
# Male               2583             2358.0       120.0             360.0
# Male               6000                0.0       141.0             360.0
#
#         Credit_History Property_Area Loan_Status
# Gender
# Male               1.0         Urban           Y
# ...

# %%
# Change Casing in  Columns
# Columns with user-provided data are ripe for corruption. People make typos, leave their caps lock on (or off), and add extra spaces where they shouldn’t.
# To change all our Gender to uppercase:
 
a=df['Gender'].str.upper()
a.head(10)
# Out:
# 0    MALE
# 1    MALE
# 2    MALE
# 3    MALE
# 4    MALE
# 5    MALE
# 6    MALE
# 7    MALE
# 8    MALE
# 9    MALE
# Name: Gender, dtype: object

# %%
# Renaming Columns in a data set

f=df.rename(columns = {"Gender":"Sex", "ApplicantIncome":"Applicant's_Amount"})
f.info()

# Here we’ve renamed ‘Gender’ to ‘Sex’ and ‘ApplicantIncome’ to simply ‘Applicant's_Amount’.

# Since this is not an in-place operation, you’ll need to save the DataFrame by assigning it to a variable.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID               614 non-null object
# Sex                   601 non-null object
# Married               611 non-null object
# Dependents            599 non-null object
# Education             614 non-null object
# Self_Employed         582 non-null object
# Applicant's_Amount    614 non-null int64
# CoapplicantIncome     614 non-null float64
# LoanAmount            592 non-null float64
# Loan_Amount_Term      600 non-null float64
# Credit_History        564 non-null float64
# Property_Area         614 non-null object
# Loan_Status           614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
# Save your results after you are done cleaning your data.
# Export it back into CSV Format for further processing in another program

f.to_csv("cleanfile.csv", encoding = "ISO-8859-1")
f.columns
# Out:
# Index(['Loan_ID', 'Sex', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Applicant's_Amount', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
 # Changing the Index of a DataFrame
    
df['Education'].is_unique
 df.head()

# %% [markdown]
# ####  Finding out correlations between the features

# %%
df.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
#correlations_data = admt.corr()['Chance'].sort_values(ascending=False)
cor=df.corr()['ApplicantIncome']
# Print the correlations
print(cor)
# Out:
# ApplicantIncome      1.000000
# CoapplicantIncome   -0.116605
# LoanAmount           0.570909
# Loan_Amount_Term    -0.045306
# Credit_History      -0.014715
# Name: ApplicantIncome, dtype: float64

# %%
#correlations_data = admt.corr()['Chance'].sort_values(ascending=False)
cor=df.corr()['LoanAmount']
# Print the correlations
print(cor)
# Out:
# ApplicantIncome      0.570909
# CoapplicantIncome    0.188619
# LoanAmount           1.000000
# Loan_Amount_Term     0.039447
# Credit_History      -0.008433
# Name: LoanAmount, dtype: float64

# %%
fig=plt.gcf()
fig.set_size_inches(10,10)
fig=sns.heatmap(df.corr(),annot=True,cmap='inferno',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %%
df_sort=df.sort_values(by=df.columns[-1],ascending=False)
df_sort.head()

#df.head()
#dftemp.head()
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 297  Female     Yes          1      Graduate            No             4666
# 311    Male      No          0  Not Graduate            No             2927
# 310  Female      No          0      Graduate            No             2917
# 309    Male     Yes          2  Not Graduate            No             7667
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 297                0.0       135.0             360.0             1.0
# 311             2405.0       111.0             360.0             1.0
# 310                0.0        84.0             360.0             1.0
# 309                0.0       185.0             360.0             NaN
#
#     Property_Area Loan_Status
# 0           Urban           Y
# 297         Urban           Y
# ...

# %%
df_sort[(df_sort['LoanAmount']>0.0)].mean().reset_index()
# Out:
#                index            0
# 0    ApplicantIncome  5404.304054
# 1  CoapplicantIncome  1642.633311
# 2         LoanAmount   146.412162
# 3   Loan_Amount_Term   342.145329
# 4     Credit_History     0.843462

# %%
df.sort_values(by="LoanAmount")
df.sample()
# Out:
#      Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 600  Female      No         3+  Graduate           NaN              416
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 600            41667.0       350.0             180.0             NaN
#
#     Property_Area Loan_Status
# 600         Urban           N

# %%
# Writing data

df.to_csv("New_file.csv", index=None)

# index=None will simply write the data as it is. If you don’t write index=None, 

# you’ll get an additional first column of 1,2,3, … until the last row.

 # data.to_csv('my_new_file.csv', index=None)

# %%
df.to_csv("New.csv", index=None)

# %%
daa=pd.read_csv("New.csv")
daa.head(2)
# Out:
#   Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0  Graduate            No             5849
# 1   Male     Yes          1  Graduate            No             4583
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N

# %%
# print the  10th row in the data set

df.loc[10]
# Out:
# Gender                   Male
# Married                   Yes
# Dependents                  2
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          3200
# CoapplicantIncome         700
# LoanAmount                 70
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Urban
# Loan_Status                 Y
# Name: 10, dtype: object

# %%
df.loc[range(4,6)]

#Subset from row 4 to 6 (excluded)
# Out:
#   Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 4   Male      No          0  Graduate            No             6000
# 5   Male     Yes          2  Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 4         Urban           Y
# 5         Urban           Y

# %%
# print the value of the 8 th row on reading score

df.loc[8, "LoanAmount"]
# Out:
# 168.0

# %%
#  Updating the dataset

df.loc[7, "ApplicantIncome "]= 5000

# %%
df.loc[7]
# Out:
# Loan_ID               LP001014
# Gender                    Male
# Married                    Yes
# Dependents                  3+
# Education             Graduate
# Self_Employed               No
# ApplicantIncome           3036
# CoapplicantIncome         2504
# LoanAmount                 158
# Loan_Amount_Term           360
# Credit_History               0
# Property_Area        Semiurban
# Loan_Status                  N
# ApplicantIncome           5000
# Name: 7, dtype: object

# %%
# Counting occurrences

df[ "Gender"].value_counts()
df.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status ApplicantIncome
# 0             1.0         Urban           Y              NaN
# 1             1.0         Rural           N              NaN

# %% [markdown]
# ### Basic Plotting with Pandas

# %%
df["LoanAmount"].plot()

# Plots the distribution (histogram)

# %%
df["LoanAmount"].hist()

# Example of .hist() output

# %%
df['ApplicantIncome'].hist(bins=50)

# %%
df.boxplot(column='ApplicantIncome', by = 'Gender')

# %%
df['ApplicantIncome'].hist(bins=50)

# %%
df['LoanAmount'].hist(bins=50)  #X-axis: the values of loan amount #Y-axis: the frequencies of different values of loan amount

# %% [markdown]
# ### Data Cleaning: Handling the Missing Values

# %%
# Checking the Missing Values in the dataset

missing_df =df.isnull().sum(axis=0).reset_index()
missing_df.columns = ['Column Name', 'Missing Values Count']
missing_df['Filling Factor (%)']=(df.shape[0]-missing_df['Missing Values Count'])/df.shape[0]*100
missing_df.sort_values('Filling Factor (%)').reset_index(drop = True)
# Out:
#           Column Name  Missing Values Count  Filling Factor (%)
# 0      Credit_History                    50           91.856678
# 1       Self_Employed                    32           94.788274
# 2          LoanAmount                    22           96.416938
# 3          Dependents                    15           97.557003
# 4    Loan_Amount_Term                    14           97.719870
# 5              Gender                    13           97.882736
# 6             Married                     3           99.511401
# 7             Loan_ID                     0          100.000000
# 8           Education                     0          100.000000
# 9     ApplicantIncome                     0          100.000000
# 10  CoapplicantIncome                     0          100.000000
# 11      Property_Area                     0          100.000000
# 12        Loan_Status                     0          100.000000

# %%
# fill with zero

df = df.fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, Male to Female
# Data columns (total 11 columns):
# Married              614 non-null object
# Dependents           614 non-null object
# Education            614 non-null object
# Self_Employed        614 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           614 non-null float64
# Loan_Amount_Term     614 non-null float64
# Credit_History       614 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 57.6+ KB

# %%
# Remove All Columns with at least one missing value

columns_with_na_dropped = df.dropna(axis=1)
columns_with_na_dropped.head()

# Remove date_first_booking column
# df_all.drop('date_first_booking', axis=1, inplace=True)
# Out:
#        Married Dependents     Education Self_Employed  ApplicantIncome  \
# Gender
# Male        No          0      Graduate            No             5849
# Male       Yes          1      Graduate            No             4583
# Male       Yes          0      Graduate           Yes             3000
# Male       Yes          0  Not Graduate            No             2583
# Male        No          0      Graduate            No             6000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Gender
# Male                  0.0         0.0             360.0             1.0
# Male               1508.0       128.0             360.0             1.0
# Male                  0.0        66.0             360.0             1.0
# Male               2358.0       120.0             360.0             1.0
# Male                  0.0       141.0             360.0             1.0
#
#        Property_Area Loan_Status
# Gender
# Male           Urban           Y
# ...

# %%
# Check any missing value after removing the missing values

missing_a =a.isnull().sum(axis=0).reset_index()
missing_a.columns = ['Column Name', 'Missing Values Count']
missing_a['Filling Factor (%)']=(a.shape[0]-missing_a['Missing Values Count'])/a.shape[0]*100
missing_a.sort_values('Filling Factor (%)').reset_index(drop = True)
# Out:
#           Column Name  Missing Values Count  Filling Factor (%)
# 0             Married                     0               100.0
# 1          Dependents                     0               100.0
# 2           Education                     0               100.0
# 3       Self_Employed                     0               100.0
# 4     ApplicantIncome                     0               100.0
# 5   CoapplicantIncome                     0               100.0
# 6          LoanAmount                     0               100.0
# 7    Loan_Amount_Term                     0               100.0
# 8      Credit_History                     0               100.0
# 9       Property_Area                     0               100.0
# 10        Loan_Status                     0               100.0

# %%
df.dropna()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %% [markdown]
# # Data Cleaning: Handling Missing Values, Character Encoding, Scaling and Normalizing Data, Inconsistent Data Entry and Parsing Dates

# %% [markdown]
# #### To be covered later
